# %%
# !pip3 install --upgrade sklearn
# Out:
# ...
#     100% |████████████████████████████████| 7.6MB 194kB/s eta 0:00:01    79% |█████████████████████████▎      | 6.0MB 6.4MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for sklearn ... done
#   Stored in directory: /Users/vlad/Library/Caches/pip/wheels/d7/db/a3/1b8041ab0be63b5c96c503df8e757cf205c2848cf9ef55f85e
# Successfully built sklearn
# ...
#   Found existing installation: scikit-learn 0.18.1
#     Uninstalling scikit-learn-0.18.1:
#       Successfully uninstalled scikit-learn-0.18.1
# ...

# %%
# %pylab inline
import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('datasets/alcohol.csv')

# %%
df
# Out:
#       Unnamed: 0  abuse  status  unemrate  age  educ  married  famsize  white  \
# 0              1      1       1       4.0   50     4        1        1      1
# 1              2      0       3       4.0   37    12        1        5      1
# 2              3      0       3       4.0   53     9        1        3      1
# 3              4      0       3       3.3   59    11        1        1      1
# 4              5      0       3       3.3   43    10        1        1      1
# 5              6      0       3       3.3   38    10        1        1      1
# 6              7      0       3       6.8   34    10        1        4      1
# 7              8      0       1       6.8   45     2        1        2      1
# 8              9      0       1       6.8   47     5        1        2      0
# 9             10      0       3       6.8   31    12        1        1      1
# 10            11      0       3       6.8   43    18        1        4      1
# ...
